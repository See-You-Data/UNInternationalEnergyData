# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in range(1,13):
    print(i)
    if i == 1:
        df = pd.read_csv('Raw Data/all_energy_statistics' + str(i) +'.csv')
    else:
        df1 = pd.read_csv('Raw Data/all_energy_statistics' + str(i) + '.csv')
        df = df.append(df1)
# Out:
# 1
# First line of this file is Kuwait                                            Kuwait
# Electricity - Gross demand    Electricity - Gross demand
# 1998                                                1997
# Kilowatt-hours, million          Kilowatt-hours, million
# 25753                                              23390
# Unnamed: 5                                           NaN
# total_electricity                      total_electricity
# Name: 0, dtype: object
# 2
# First line of this file is India                                                                            India
# Brown coal briquettes - final consumption    Brown coal briquettes - final consumption
# 1994                                                                              1993
# Metric tons,  thousand                                          Metric tons,  thousand
# 1580                                                                              1494
# ...

# %%
for i in range(2,13)
# Out:
#       country_or_area                      commodity_transaction  year  \
# 0             Austria         Additives and Oxygenates - Exports  1996
# 1             Austria         Additives and Oxygenates - Exports  1995
# 2             Belgium         Additives and Oxygenates - Exports  2014
# 3             Belgium         Additives and Oxygenates - Exports  2013
# 4             Belgium         Additives and Oxygenates - Exports  2012
# ...               ...                                        ...   ...
# 99994           India  Brown coal briquettes - final consumption  1999
# 99995           India  Brown coal briquettes - final consumption  1998
# 99996           India  Brown coal briquettes - final consumption  1997
# 99997           India  Brown coal briquettes - final consumption  1996
# 99998           India  Brown coal briquettes - final consumption  1995
#
#                          unit  quantity  quantity_footnotes  \
# ...
